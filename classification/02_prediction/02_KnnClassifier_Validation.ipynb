# %% [markdown]
# # Data loading

# %% [markdown]
# ## Evaluation dataset

# %%
import os

# Limit the number of threads used by various linear algebra libraries
# to avoid oversubscription and improve efficiency in multiprocessing environments
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"

import numpy as np
import pandas as pd

# Set patch size used for processing image tiles
patch_size = 128

# Load evaluation metadata (downsampled version)
eval_csv = "/home/lbh/projects_dir/BigSlice/dataset/test_set_with_coo.csv"
eval_df = pd.read_csv(eval_csv, index_col=0)
eval_df
# Out:
#                                 spot organ     subregion    level1_annotation  \
# Unnamed: 0
# 1           AACAACGACAGCCTACAA_0_0_0    LU       Alveoli  blood & immune cell
# 11          AACACACGGTACAGAGCT_0_0_0    LU       Alveoli  blood & immune cell
# 12          AACACACGGTACGGCATA_0_0_0    LU       Alveoli      epithelial cell
# 20          AACACTACGCGAACGGTA_0_0_0    LU       Alveoli      epithelial cell
# 24          AACACTACGGTCCACCAA_0_0_0    LU       Alveoli      epithelial cell
# ...                              ...   ...           ...                  ...
# 2330867         TTGTTGACCGTGTACACT_1    HE  Heart Tissue          muscle cell
# 2330869         TTGTTGACCTCTTGACAG_1    HE  Heart Tissue          muscle cell
# 2330870         TTGTTGCGAAGATGCGTC_1    HE  Heart Tissue          muscle cell
# 2330872         TTGTTGCGAGTCTTCACA_1    HE  Heart Tissue          muscle cell
# 2330875         TTGTTGGAGCGCTTCTTC_1    HE  Heart Tissue          muscle cell
#
#                       level2_annotation    level0_annotation  \
# Unnamed: 0
# 1                                B cell               B cell
# 11                               B cell               B cell
# 12          specialized epithelial cell      epithelial cell
# 20                           pneumocyte    type I pneumocyte
# 24                           pneumocyte    type I pneumocyte
# ...                                 ...                  ...
# 2330867             cardiac muscle cell  cardiac muscle cell
# 2330869             cardiac muscle cell  cardiac muscle cell
# 2330870             cardiac muscle cell  cardiac muscle cell
# 2330872             cardiac muscle cell  cardiac muscle cell
# 2330875             cardiac muscle cell  cardiac muscle cell
#
#            celltype_prediction_1  score_prediction_1  \
# Unnamed: 0
# 1                         B cell              0.4480
# 11                        B cell              0.5057
# 12               epithelial cell              0.4006
# 20             type I pneumocyte              0.8655
# 24             type I pneumocyte              1.0000
# ...                          ...                 ...
# 2330867      cardiac muscle cell              0.5973
# 2330869      cardiac muscle cell              0.8586
# 2330870      cardiac muscle cell              0.6812
# 2330872      cardiac muscle cell              0.4873
# 2330875      cardiac muscle cell              0.5192
#
#                      celltype_prediction_2  score_prediction_2  ...  \
# Unnamed: 0                                                      ...
# 1                          epithelial cell              0.2924  ...
# 11                         epithelial cell              0.2555  ...
# 12                                  T cell              0.3183  ...
# 20                        endothelial cell              0.0980  ...
# 24                                     NaN              0.0000  ...
# ...                                    ...                 ...  ...
# 2330867                         fibroblast              0.2106  ...
# 2330869     regular atrial cardiac myocyte              0.1414  ...
# 2330870                         fibroblast              0.1929  ...
# 2330872       fibroblast of cardiac tissue              0.2563  ...
# 2330875     regular atrial cardiac myocyte              0.3176  ...
#
#            x_scaled_image  y_scaled_image  x_scaled_image_organ  \
# Unnamed: 0
# 1             2030.518557     3122.431157            804.518557
# 11            2077.235895     3373.985738            851.235895
# 12            1659.375258     3342.541415            433.375258
# 20            2282.273102     3522.223258           1056.273102
# 24            2061.663449     3266.176632            835.663449
# ...                   ...             ...                   ...
# 2330867        747.736645     3558.503127            386.736645
# 2330869       1426.432052     3603.338014           1065.432052
# 2330870       1550.773196     3728.875699           1189.773196
# 2330872       1188.111528     3917.182227            827.111528
# 2330875       1289.138707     3249.142403            928.138707
#
#             y_scaled_image_organ   batch  organ_encoded subregion_encoded  \
# Unnamed: 0
# 1                     659.431157  CTRL_1              8                 0
# 11                    910.985738  CTRL_1              8                 0
# 12                    879.541415  CTRL_1              8                 0
# 20                   1059.223258  CTRL_1              8                 0
# 24                    803.176632  CTRL_1              8                 0
# ...                          ...     ...            ...               ...
# 2330867               821.503127   LPS_2              4                17
# 2330869               866.338014   LPS_2              4                17
# 2330870               991.875699   LPS_2              4                17
# 2330872              1180.182227   LPS_2              4                17
# 2330875               512.142403   LPS_2              4                17
#
#             level0_annotation_encoded  level1_annotation_encoded  \
# Unnamed: 0
# 1                                   0                          1
# 11                                  0                          1
# 12                                104                          6
# 20                                339                          6
# 24                                339                          6
# ...                               ...                        ...
# 2330867                            61                         13
# 2330869                            61                         13
# 2330870                            61                         13
# 2330872                            61                         13
# 2330875                            61                         13
#
#             level2_annotation_encoded
# Unnamed: 0
# 1                                   0
# 11                                  0
# 12                                 68
# 20                                 58
# 24                                 58
# ...                               ...
# 2330867                             7
# 2330869                             7
# 2330870                             7
# 2330872                             7
# 2330875                             7
#
# [466176 rows x 22 columns]

# %%
coo_eval = eval_df[['x_scaled_image', 'y_scaled_image']].values.astype(np.float32)

# %%
import numpy as np

# Load extracted image features for the evaluation set
# Features are saved as .npy file and converted to float32 for compatibility and efficiency
X_eval = np.load(f"/home/lbh/projects_dir/BigSlice/dataset/uni_validation_feature_{patch_size}_all.npy").astype(np.float32)

# Print the shape of the loaded feature array (expected: [N, 1536])
X_eval.shape
# Out:
# (466176, 1536)

# %% [markdown]
# ## Train set

# %%
import numpy as np
import pandas as pd

# Load full annotation table with 'spot' as index
all_df = pd.read_csv('/home/lbh/projects_dir/BigSlice/Celltype_Annotations/all_annotations.csv', index_col=0)

# Load sampled training set with 'filename' as index
train_df = pd.read_csv("/home/lbh/projects_dir/BigSlice/dataset/train_8k_samples.csv", index_col=0)

# Filter annotations to only include rows present in the training set
subset_df = all_df[all_df['spot'].isin(train_df['filename'])]

# Reorder subset_df to match the order in train_df['filename']
# This ensures that labels align with extracted image features
subset_df_sorted = subset_df.set_index('spot').loc[train_df['filename']].reset_index()

# Display the sorted subset of annotation DataFrame
subset_df_sorted
# Out:
#                            spot organ                        subregion  \
# 0      CAGTTCCAGATTGGTGCT_0_0_0    BR                     Fiber Tracts
# 1          CGACGAGTAAGCATCTAC_1    BM               Bone Marrow Tissue
# 2      GATTCTGACCGCATAAGC_0_0_0    BR  Cerebellar Cortex (Gran. Layer)
# 3        CGCATCTCATGGTTCACT_1_0    MU                    Muscle Tissue
# 4          AGTCAGACTGCATACACA_1    MU                    Muscle Tissue
# ...                         ...   ...                              ...
# 79995  GTCTTCACAGTAGAACCT_0_0_0    MU                    Muscle Tissue
# 79996    GCTTCCTAAGTCGATTCG_1_0    LU                          Alveoli
# 79997    GTACTTGGTTCTCTAGCG_1_0    MU                    Muscle Tissue
# 79998  TTGTCTCGTGAAGCAACG_1_0_0    BF                 Brown Fat Tissue
# 79999  ATATCACCGTTCACAGCC_1_0_0    LI                       Periportal
#
#          level1_annotation        level2_annotation  \
# 0               glial cell          oligodendrocyte
# 1      blood & immune cell  hematopoietic stem cell
# 2         mesenchymal cell             granule cell
# 3              muscle cell              muscle cell
# 4              muscle cell     skeletal muscle cell
# ...                    ...                      ...
# 79995          muscle cell     skeletal muscle cell
# 79996      epithelial cell               pneumocyte
# 79997          muscle cell     skeletal muscle cell
# 79998           adipocytes                adipocyte
# 79999     mesenchymal cell               fibroblast
#
#                             level0_annotation  \
# 0                             oligodendrocyte
# 1                     hematopoietic stem cell
# 2                                granule cell
# 3                                 muscle cell
# 4      multi-potent skeletal muscle stem cell
# ...                                       ...
# 79995  multi-potent skeletal muscle stem cell
# 79996                      type II pneumocyte
# 79997  multi-potent skeletal muscle stem cell
# 79998                          brown fat cell
# 79999                              fibroblast
#
#                         celltype_prediction_1  score_prediction_1  \
# 0                             oligodendrocyte              0.9458
# 1                     hematopoietic stem cell              0.4734
# 2                                granule cell              0.4037
# 3                                 muscle cell              0.3445
# 4      multi-potent skeletal muscle stem cell              0.4516
# ...                                       ...                 ...
# 79995  multi-potent skeletal muscle stem cell              0.4073
# 79996                      type II pneumocyte              0.3775
# 79997  multi-potent skeletal muscle stem cell              0.5797
# 79998                          brown fat cell              0.7443
# 79999                              fibroblast              0.5778
#
#                          celltype_prediction_2  score_prediction_2  ...  \
# 0                                     tanycyte              0.0542  ...
# 1                 hematopoietic precursor cell              0.4092  ...
# 2                            inhibitory neuron              0.3906  ...
# 3       multi-potent skeletal muscle stem cell              0.3324  ...
# 4                      cell of skeletal muscle              0.3373  ...
# ...                                        ...                 ...  ...
# 79995                  cell of skeletal muscle              0.3209  ...
# 79996                      alveolar macrophage              0.3690  ...
# 79997                              muscle cell              0.2503  ...
# 79998  mesenchymal stem cell of adipose tissue              0.1687  ...
# 79999                    hepatic stellate cell              0.3376  ...
#
#       x_scaled_image  y_scaled_image  x_scaled_image_organ  \
# 0        2123.953233      714.694460            932.953233
# 1        1804.636364     3092.220296           1804.636364
# 2        2648.225586     1056.089962           1457.225586
# 3        2083.518463     6556.506308           2083.518463
# 4        2387.485473     2854.595392           2387.485473
# ...              ...             ...                   ...
# 79995    1013.118744     2071.292375           1013.118744
# 79996    2236.420806     3806.917170            975.420806
# 79997    2459.295408     5690.811849           2459.295408
# 79998    1655.630740      610.229951           1655.630740
# 79999    1265.464855     4479.764509           1265.464855
#
#        y_scaled_image_organ   batch  organ_encoded subregion_encoded  \
# 0                714.694460  CTRL_1              2                13
# 1               3092.220296   LPS_2              1                 2
# 2               1056.089962  CTRL_1              2                 7
# 3               6556.506308   LPS_1              9                27
# 4               2854.595392   LPS_2              9                27
# ...                     ...     ...            ...               ...
# 79995           2071.292375  CTRL_1              9                27
# 79996            856.917170   LPS_1              8                 0
# 79997           5690.811849   LPS_1              9                27
# 79998            610.229951  CTRL_2              0                 5
# 79999           1425.764509  CTRL_2              6                32
#
#        level0_annotation_encoded  level1_annotation_encoded  \
# 0                            257                          9
# 1                            145                          1
# 2                            136                         12
# 3                            227                         13
# 4                            226                         13
# ...                          ...                        ...
# 79995                        226                         13
# 79996                        341                          6
# 79997                        226                         13
# 79998                         55                          0
# 79999                        125                         12
#
#        level2_annotation_encoded
# 0                             52
# 1                             31
# 2                             27
# 3                             46
# 4                             66
# ...                          ...
# 79995                         66
# 79996                         58
# 79997                         66
# 79998                          3
# 79999                         21
#
# [80000 rows x 22 columns]

# %% [markdown]
# ### Update annotations

# %%
import numpy as np

def update_skin_subregion(df):
    """
    Update subregion annotations for 'SK' (skin) organ entries.
    Replaces missing or 'other'-like subregion values with 'Skin_other'.

    Args:
        df (pd.DataFrame): DataFrame with 'organ' and 'subregion' columns.

    Returns:
        pd.DataFrame: Updated DataFrame.
        int: Number of rows modified.
    """
    # Condition: rows where organ is 'SK' and subregion is NA or 'other'
    condition = (df['organ'] == 'SK') & (
        df['subregion'].isna() | (df['subregion'].astype(str).str.lower() == 'other')
    )
    num_updated = condition.sum()

    # Apply update: set subregion to 'Skin_other' for matching rows
    df.loc[condition, 'subregion'] = 'Skin_other'
    return df, num_updated

# Apply the update to training annotations
subset_df_sorted, num_updated_train = update_skin_subregion(subset_df_sorted)

# Print the number of updated rows
print(f"Train set updated: {num_updated_train} rows")
# Out:
# Train set updated: 7632 rows

# %%
np.unique(subset_df_sorted['subregion'])
# Out:
# array(['Alveoli', 'Blood Vessel', 'Bone Marrow Tissue', 'Bronchi',
#        'Bronchioles', 'Brown Fat Tissue', 'Caudoputamen',
#        'Cerebellar Cortex (Gran. Layer)',
#        'Cerebellar Cortex (Mol. Layer)', 'Cerebral Cortex',
#        'Colon Tissue', 'Dermis', 'Epidermis', 'Fiber Tracts',
#        'Foveolar Epithelium', 'Gastric Glands (Chief Cell Rich)',
#        'Gastric Glands (Parietal Cell Rich)', 'Heart Tissue',
#        'Hypodermis', 'Hyppocampus', 'Inner Medulla',
#        'Inner Stripe of Outer Medulla', 'Lymph Node Tissue',
#        'Marginal Zone', 'Meninges', 'Midbrain', 'Midbrain/Hindbrain',
#        'Muscle Tissue', 'Other', 'Outer Stripe of Outer Medulla',
#        'Pancreas Tissue', 'Pericentral', 'Periportal', 'Red Pulp',
#        'Renal Cortex', 'Skin_other', 'Small Intestine Tissue',
#        'Spinal Cord', 'Thalamus', 'Thymic Cortex', 'Thymic Medulla',
#        'Ventricle', 'White Pulp'], dtype=object)

# %% [markdown]
# ### Data preparation

# %%
import os
from tqdm import tqdm

# Initialize storage for each of the 5 label levels
y_train_levels = [[] for _ in range(5)]

batch_size = 64  # Batch size for label processing (adjust if needed)
label_columns = ["organ", "subregion", "level1_annotation", "level2_annotation", "level0_annotation"]

# Iterate through the annotation DataFrame in batches
for i in tqdm(range(0, len(subset_df_sorted), batch_size), desc="Extracting train features"):
    batch_df = subset_df_sorted.iloc[i:i+batch_size]
    batch_labels = [[] for _ in range(5)]  # Temporary storage for this batch

    # Column names to extract (can be modified for encoded labels)
    encoded_columns = [f"{col}" for col in label_columns]

    # Extract labels for each level in this batch
    for _, row in batch_df.iterrows():
        for j, col in enumerate(encoded_columns):
            batch_labels[j].append(row[col])

    # Append batch labels to the overall label lists
    for j in range(5):
        y_train_levels[j].extend(batch_labels[j])
# Out:
# Extracting train features:   0%|          | 0/1250 [00:00<?, ?it/s]
# Extracting train features: 100%|██████████| 1250/1250 [00:03<00:00, 398.75it/s]

# %%
# Extract scaled spatial coordinates ('x_scaled_image', 'y_scaled_image') for training samples
# Convert to float32 NumPy array for downstream tasks (e.g., KNN, spatial clustering)
coo_train = subset_df_sorted[['x_scaled_image', 'y_scaled_image']].values.astype(np.float32)

# Check the shape of the coordinate array (should match the number of training samples)
coo_train.shape
# Out:
# (80000, 2)

# %%
patch_size = 128  # Define patch size used during feature extraction

# Load precomputed feature vectors for the training set
# Features are stored in a .npy file and converted to float32 for consistency
X_train = np.load(f"/home/lbh/projects_dir/BigSlice/dataset/uni_feature_{patch_size}.npy").astype(np.float32)

# Display the shape of the feature array (expected shape: [N, 1536])
X_train.shape
# Out:
# (80000, 1536)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np

# 1. Concatenate spatial coordinates and image features
# Shape: [N, D], where D = 2 (coords) + 1536 (features)
x_all = np.hstack((coo_train, X_train))  # shape: [20000, D]

# 2. Normalize features using StandardScaler (zero mean, unit variance)
scaler = StandardScaler()
x_all_normalized = scaler.fit_transform(x_all)

# 3. Apply PCA to reduce dimensionality to 200 components
# This helps improve efficiency and reduce noise for downstream tasks
pca = PCA(n_components=200, random_state=42)
x_all_reduced = pca.fit_transform(x_all_normalized)

# %%
# Concatenate spatial coordinates and extracted image features for the evaluation set
# Shape: [N, D], where D = 2 (coords) + 1536 (features)
x_all_eval = np.hstack((coo_eval, X_eval))  # shape: [N, D]

# WARNING: This re-fits the scaler on the evaluation set — not recommended!
# In practice, you should reuse the `scaler` fitted on the training set for consistency

scaler = StandardScaler()
x_eval_normalized = scaler.fit_transform(x_all_eval)  # <-- should ideally use scaler.transform()

# Apply PCA transformation using the model fitted on training data
X_eval_reduced = pca.transform(x_eval_normalized)  # shape: [N, 200]

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import time

# Set batch size for inference
batch_size = 1000

# Dictionary to store predictions
predictions = {}

# Define the label levels to be predicted
label_columns = ['organ', 'subregion', 'level1_annotation', 'level2_annotation', 'level0_annotation']

# Loop over each label level
for i, y_train in enumerate(y_train_levels):
    print(f"\n=== Processing label: {label_columns[i]} ===")
    
    # --- Train KNN classifier ---
    start_train = time.time()
    knn = KNeighborsClassifier(n_neighbors=5, n_jobs=16)  # Use 16 threads for parallel search
    knn.fit(x_all_reduced, y_train)  # Fit on reduced training features
    end_train = time.time()
    print(f"Training time: {end_train - start_train:.2f} seconds")

    # --- Batch prediction ---
    print(f"Predicting {label_columns[i]} in batches...")
    y_preds = []
    start_predict = time.time()

    for j in range(0, len(X_eval_reduced), batch_size):
        batch = X_eval_reduced[j:j+batch_size]
        batch_pred = knn.predict(batch)
        y_preds.append(batch_pred)

        # Log progress every 10 batches with estimated remaining time
        if (j // batch_size) % 10 == 0 and j > 0:
            elapsed = time.time() - start_predict
            done_batches = j // batch_size
            total_batches = len(X_eval_reduced) // batch_size + 1
            eta = elapsed / done_batches * (total_batches - done_batches)
            print(f"Processed {j}/{len(X_eval_reduced)} samples "
                  f"({done_batches}/{total_batches} batches), "
                  f"elapsed: {elapsed:.1f}s, ETA: {eta:.1f}s")

    # --- Store and record predictions ---
    y_pred = np.concatenate(y_preds)  # Flatten batched predictions
    eval_df[f"{label_columns[i]}_pred"] = y_pred  # Save predictions to DataFrame

    total_predict_time = time.time() - start_predict
    print(f"Prediction time: {total_predict_time:.2f} seconds")

print("\n✅ All predictions completed.")
# Out:
# === Processing label: organ ===
# Training time: 0.05 seconds
# Predicting organ in batches...
# Processed 10000/466176 samples (10/467 batches), elapsed: 9.6s, ETA: 440.3s
# Processed 20000/466176 samples (20/467 batches), elapsed: 18.4s, ETA: 410.4s
# Processed 30000/466176 samples (30/467 batches), elapsed: 27.1s, ETA: 394.7s
# Processed 40000/466176 samples (40/467 batches), elapsed: 35.9s, ETA: 382.9s
# Processed 50000/466176 samples (50/467 batches), elapsed: 44.7s, ETA: 372.4s
# Processed 60000/466176 samples (60/467 batches), elapsed: 53.5s, ETA: 362.6s
# Processed 70000/466176 samples (70/467 batches), elapsed: 62.2s, ETA: 352.7s
# Processed 80000/466176 samples (80/467 batches), elapsed: 70.9s, ETA: 343.0s
# Processed 90000/466176 samples (90/467 batches), elapsed: 79.7s, ETA: 333.8s
# Processed 100000/466176 samples (100/467 batches), elapsed: 88.5s, ETA: 324.6s
# Processed 110000/466176 samples (110/467 batches), elapsed: 97.2s, ETA: 315.5s
# Processed 120000/466176 samples (120/467 batches), elapsed: 106.0s, ETA: 306.4s
# Processed 130000/466176 samples (130/467 batches), elapsed: 114.7s, ETA: 297.4s
# Processed 140000/466176 samples (140/467 batches), elapsed: 123.5s, ETA: 288.5s
# Processed 150000/466176 samples (150/467 batches), elapsed: 132.3s, ETA: 279.6s
# Processed 160000/466176 samples (160/467 batches), elapsed: 141.1s, ETA: 270.7s
# Processed 170000/466176 samples (170/467 batches), elapsed: 149.8s, ETA: 261.7s
# Processed 180000/466176 samples (180/467 batches), elapsed: 158.6s, ETA: 252.9s
# Processed 190000/466176 samples (190/467 batches), elapsed: 167.4s, ETA: 244.0s
# Processed 200000/466176 samples (200/467 batches), elapsed: 176.1s, ETA: 235.1s
# Processed 210000/466176 samples (210/467 batches), elapsed: 184.9s, ETA: 226.3s
# Processed 220000/466176 samples (220/467 batches), elapsed: 193.7s, ETA: 217.4s
# Processed 230000/466176 samples (230/467 batches), elapsed: 202.4s, ETA: 208.6s
# Processed 240000/466176 samples (240/467 batches), elapsed: 211.2s, ETA: 199.8s
# Processed 250000/466176 samples (250/467 batches), elapsed: 220.0s, ETA: 191.0s
# Processed 260000/466176 samples (260/467 batches), elapsed: 228.8s, ETA: 182.1s
# Processed 270000/466176 samples (270/467 batches), elapsed: 237.6s, ETA: 173.3s
# Processed 280000/466176 samples (280/467 batches), elapsed: 246.3s, ETA: 164.5s
# Processed 290000/466176 samples (290/467 batches), elapsed: 255.1s, ETA: 155.7s
# Processed 300000/466176 samples (300/467 batches), elapsed: 263.9s, ETA: 146.9s
# Processed 310000/466176 samples (310/467 batches), elapsed: 272.7s, ETA: 138.1s
# Processed 320000/466176 samples (320/467 batches), elapsed: 281.4s, ETA: 129.3s
# Processed 330000/466176 samples (330/467 batches), elapsed: 290.2s, ETA: 120.5s
# Processed 340000/466176 samples (340/467 batches), elapsed: 298.9s, ETA: 111.7s
# Processed 350000/466176 samples (350/467 batches), elapsed: 307.7s, ETA: 102.9s
# Processed 360000/466176 samples (360/467 batches), elapsed: 316.5s, ETA: 94.1s
# Processed 370000/466176 samples (370/467 batches), elapsed: 325.3s, ETA: 85.3s
# Processed 380000/466176 samples (380/467 batches), elapsed: 334.0s, ETA: 76.5s
# Processed 390000/466176 samples (390/467 batches), elapsed: 342.8s, ETA: 67.7s
# Processed 400000/466176 samples (400/467 batches), elapsed: 351.6s, ETA: 58.9s
# Processed 410000/466176 samples (410/467 batches), elapsed: 360.3s, ETA: 50.1s
# Processed 420000/466176 samples (420/467 batches), elapsed: 369.1s, ETA: 41.3s
# Processed 430000/466176 samples (430/467 batches), elapsed: 377.9s, ETA: 32.5s
# Processed 440000/466176 samples (440/467 batches), elapsed: 386.7s, ETA: 23.7s
# Processed 450000/466176 samples (450/467 batches), elapsed: 395.5s, ETA: 14.9s
# Processed 460000/466176 samples (460/467 batches), elapsed: 404.2s, ETA: 6.2s
# Prediction time: 408.80 seconds
#
# === Processing label: subregion ===
# Training time: 0.08 seconds
# Predicting subregion in batches...
# Processed 10000/466176 samples (10/467 batches), elapsed: 9.6s, ETA: 440.9s
# Processed 20000/466176 samples (20/467 batches), elapsed: 18.4s, ETA: 411.3s
# Processed 30000/466176 samples (30/467 batches), elapsed: 27.2s, ETA: 395.7s
# Processed 40000/466176 samples (40/467 batches), elapsed: 35.9s, ETA: 383.6s
# Processed 50000/466176 samples (50/467 batches), elapsed: 44.7s, ETA: 372.8s
# Processed 60000/466176 samples (60/467 batches), elapsed: 53.5s, ETA: 362.8s
# Processed 70000/466176 samples (70/467 batches), elapsed: 62.3s, ETA: 353.1s
# Processed 80000/466176 samples (80/467 batches), elapsed: 71.0s, ETA: 343.5s
# Processed 90000/466176 samples (90/467 batches), elapsed: 79.8s, ETA: 334.2s
# Processed 100000/466176 samples (100/467 batches), elapsed: 88.5s, ETA: 325.0s
# Processed 110000/466176 samples (110/467 batches), elapsed: 97.3s, ETA: 315.9s
# Processed 120000/466176 samples (120/467 batches), elapsed: 106.1s, ETA: 306.8s
# Processed 130000/466176 samples (130/467 batches), elapsed: 114.9s, ETA: 297.8s
# Processed 140000/466176 samples (140/467 batches), elapsed: 123.6s, ETA: 288.8s
# Processed 150000/466176 samples (150/467 batches), elapsed: 132.4s, ETA: 279.8s
# Processed 160000/466176 samples (160/467 batches), elapsed: 141.2s, ETA: 270.9s
# Processed 170000/466176 samples (170/467 batches), elapsed: 149.9s, ETA: 261.9s
# Processed 180000/466176 samples (180/467 batches), elapsed: 158.7s, ETA: 253.0s
# Processed 190000/466176 samples (190/467 batches), elapsed: 167.5s, ETA: 244.1s
# Processed 200000/466176 samples (200/467 batches), elapsed: 176.2s, ETA: 235.3s
# Processed 210000/466176 samples (210/467 batches), elapsed: 185.0s, ETA: 226.4s
# Processed 220000/466176 samples (220/467 batches), elapsed: 193.8s, ETA: 217.6s
# Processed 230000/466176 samples (230/467 batches), elapsed: 202.5s, ETA: 208.7s
# Processed 240000/466176 samples (240/467 batches), elapsed: 211.3s, ETA: 199.9s
# Processed 250000/466176 samples (250/467 batches), elapsed: 220.1s, ETA: 191.0s
# Processed 260000/466176 samples (260/467 batches), elapsed: 228.9s, ETA: 182.2s
# Processed 270000/466176 samples (270/467 batches), elapsed: 237.6s, ETA: 173.4s
# Processed 280000/466176 samples (280/467 batches), elapsed: 246.4s, ETA: 164.6s
# Processed 290000/466176 samples (290/467 batches), elapsed: 255.2s, ETA: 155.7s
# Processed 300000/466176 samples (300/467 batches), elapsed: 263.9s, ETA: 146.9s
# Processed 310000/466176 samples (310/467 batches), elapsed: 272.7s, ETA: 138.1s
# Processed 320000/466176 samples (320/467 batches), elapsed: 281.5s, ETA: 129.3s
# Processed 330000/466176 samples (330/467 batches), elapsed: 290.2s, ETA: 120.5s
# Processed 340000/466176 samples (340/467 batches), elapsed: 299.0s, ETA: 111.7s
# Processed 350000/466176 samples (350/467 batches), elapsed: 307.8s, ETA: 102.9s
# Processed 360000/466176 samples (360/467 batches), elapsed: 316.6s, ETA: 94.1s
# Processed 370000/466176 samples (370/467 batches), elapsed: 325.3s, ETA: 85.3s
# Processed 380000/466176 samples (380/467 batches), elapsed: 334.1s, ETA: 76.5s
# Processed 390000/466176 samples (390/467 batches), elapsed: 342.9s, ETA: 67.7s
# Processed 400000/466176 samples (400/467 batches), elapsed: 351.6s, ETA: 58.9s
# Processed 410000/466176 samples (410/467 batches), elapsed: 360.4s, ETA: 50.1s
# Processed 420000/466176 samples (420/467 batches), elapsed: 369.2s, ETA: 41.3s
# Processed 430000/466176 samples (430/467 batches), elapsed: 378.0s, ETA: 32.5s
# Processed 440000/466176 samples (440/467 batches), elapsed: 386.7s, ETA: 23.7s
# Processed 450000/466176 samples (450/467 batches), elapsed: 395.5s, ETA: 14.9s
# Processed 460000/466176 samples (460/467 batches), elapsed: 404.3s, ETA: 6.2s
# Prediction time: 408.90 seconds
#
# === Processing label: level1_annotation ===
# Training time: 0.07 seconds
# Predicting level1_annotation in batches...
# Processed 10000/466176 samples (10/467 batches), elapsed: 9.6s, ETA: 440.3s
# Processed 20000/466176 samples (20/467 batches), elapsed: 18.4s, ETA: 411.4s
# Processed 30000/466176 samples (30/467 batches), elapsed: 27.2s, ETA: 396.0s
# Processed 40000/466176 samples (40/467 batches), elapsed: 36.0s, ETA: 383.8s
# Processed 50000/466176 samples (50/467 batches), elapsed: 44.7s, ETA: 372.9s
# Processed 60000/466176 samples (60/467 batches), elapsed: 53.5s, ETA: 362.8s
# Processed 70000/466176 samples (70/467 batches), elapsed: 62.2s, ETA: 353.0s
# Processed 80000/466176 samples (80/467 batches), elapsed: 71.0s, ETA: 343.6s
# Processed 90000/466176 samples (90/467 batches), elapsed: 79.8s, ETA: 334.2s
# Processed 100000/466176 samples (100/467 batches), elapsed: 88.6s, ETA: 325.0s
# Processed 110000/466176 samples (110/467 batches), elapsed: 97.3s, ETA: 315.9s
# Processed 120000/466176 samples (120/467 batches), elapsed: 106.1s, ETA: 306.8s
# Processed 130000/466176 samples (130/467 batches), elapsed: 114.9s, ETA: 297.8s
# Processed 140000/466176 samples (140/467 batches), elapsed: 123.7s, ETA: 288.8s
# Processed 150000/466176 samples (150/467 batches), elapsed: 132.5s, ETA: 279.9s
# Processed 160000/466176 samples (160/467 batches), elapsed: 141.2s, ETA: 271.0s
# Processed 170000/466176 samples (170/467 batches), elapsed: 150.0s, ETA: 262.1s
# Processed 180000/466176 samples (180/467 batches), elapsed: 158.8s, ETA: 253.2s
# Processed 190000/466176 samples (190/467 batches), elapsed: 167.6s, ETA: 244.3s
# Processed 200000/466176 samples (200/467 batches), elapsed: 176.3s, ETA: 235.4s
# Processed 210000/466176 samples (210/467 batches), elapsed: 185.1s, ETA: 226.6s
# Processed 220000/466176 samples (220/467 batches), elapsed: 193.9s, ETA: 217.7s
# Processed 230000/466176 samples (230/467 batches), elapsed: 202.7s, ETA: 208.8s
# Processed 240000/466176 samples (240/467 batches), elapsed: 211.5s, ETA: 200.0s
# Processed 250000/466176 samples (250/467 batches), elapsed: 220.2s, ETA: 191.2s
# Processed 260000/466176 samples (260/467 batches), elapsed: 229.0s, ETA: 182.3s
# Processed 270000/466176 samples (270/467 batches), elapsed: 237.8s, ETA: 173.5s
# Processed 280000/466176 samples (280/467 batches), elapsed: 246.6s, ETA: 164.7s
# Processed 290000/466176 samples (290/467 batches), elapsed: 255.4s, ETA: 155.9s
# Processed 300000/466176 samples (300/467 batches), elapsed: 264.2s, ETA: 147.0s
# Processed 310000/466176 samples (310/467 batches), elapsed: 272.9s, ETA: 138.2s
# Processed 320000/466176 samples (320/467 batches), elapsed: 281.7s, ETA: 129.4s
# Processed 330000/466176 samples (330/467 batches), elapsed: 290.5s, ETA: 120.6s
# Processed 340000/466176 samples (340/467 batches), elapsed: 299.3s, ETA: 111.8s
# Processed 350000/466176 samples (350/467 batches), elapsed: 308.1s, ETA: 103.0s
# Processed 360000/466176 samples (360/467 batches), elapsed: 316.9s, ETA: 94.2s
# Processed 370000/466176 samples (370/467 batches), elapsed: 325.7s, ETA: 85.4s
# Processed 380000/466176 samples (380/467 batches), elapsed: 334.4s, ETA: 76.6s
# Processed 390000/466176 samples (390/467 batches), elapsed: 343.2s, ETA: 67.8s
# Processed 400000/466176 samples (400/467 batches), elapsed: 352.0s, ETA: 59.0s
# Processed 410000/466176 samples (410/467 batches), elapsed: 360.8s, ETA: 50.2s
# Processed 420000/466176 samples (420/467 batches), elapsed: 369.6s, ETA: 41.4s
# Processed 430000/466176 samples (430/467 batches), elapsed: 378.3s, ETA: 32.6s
# Processed 440000/466176 samples (440/467 batches), elapsed: 387.1s, ETA: 23.8s
# Processed 450000/466176 samples (450/467 batches), elapsed: 395.9s, ETA: 15.0s
# Processed 460000/466176 samples (460/467 batches), elapsed: 404.7s, ETA: 6.2s
# Prediction time: 409.31 seconds
#
# === Processing label: level2_annotation ===
# Training time: 0.07 seconds
# Predicting level2_annotation in batches...
# Processed 10000/466176 samples (10/467 batches), elapsed: 9.7s, ETA: 441.7s
# Processed 20000/466176 samples (20/467 batches), elapsed: 18.5s, ETA: 412.5s
# Processed 30000/466176 samples (30/467 batches), elapsed: 27.2s, ETA: 396.9s
# Processed 40000/466176 samples (40/467 batches), elapsed: 36.0s, ETA: 384.6s
# Processed 50000/466176 samples (50/467 batches), elapsed: 44.8s, ETA: 373.7s
# Processed 60000/466176 samples (60/467 batches), elapsed: 53.6s, ETA: 363.5s
# Processed 70000/466176 samples (70/467 batches), elapsed: 62.4s, ETA: 353.7s
# Processed 80000/466176 samples (80/467 batches), elapsed: 71.1s, ETA: 344.2s
# Processed 90000/466176 samples (90/467 batches), elapsed: 79.9s, ETA: 334.8s
# Processed 100000/466176 samples (100/467 batches), elapsed: 88.7s, ETA: 325.5s
# Processed 110000/466176 samples (110/467 batches), elapsed: 97.5s, ETA: 316.4s
# Processed 120000/466176 samples (120/467 batches), elapsed: 106.3s, ETA: 307.3s
# Processed 130000/466176 samples (130/467 batches), elapsed: 115.1s, ETA: 298.3s
# Processed 140000/466176 samples (140/467 batches), elapsed: 123.8s, ETA: 289.3s
# Processed 150000/466176 samples (150/467 batches), elapsed: 132.6s, ETA: 280.3s
# Processed 160000/466176 samples (160/467 batches), elapsed: 141.4s, ETA: 271.3s
# Processed 170000/466176 samples (170/467 batches), elapsed: 150.2s, ETA: 262.4s
# Processed 180000/466176 samples (180/467 batches), elapsed: 159.0s, ETA: 253.5s
# Processed 190000/466176 samples (190/467 batches), elapsed: 167.7s, ETA: 244.6s
# Processed 200000/466176 samples (200/467 batches), elapsed: 176.5s, ETA: 235.7s
# Processed 210000/466176 samples (210/467 batches), elapsed: 185.3s, ETA: 226.8s
# Processed 220000/466176 samples (220/467 batches), elapsed: 194.1s, ETA: 217.9s
# Processed 230000/466176 samples (230/467 batches), elapsed: 202.9s, ETA: 209.0s
# Processed 240000/466176 samples (240/467 batches), elapsed: 211.7s, ETA: 200.2s
# Processed 250000/466176 samples (250/467 batches), elapsed: 220.4s, ETA: 191.3s
# Processed 260000/466176 samples (260/467 batches), elapsed: 229.2s, ETA: 182.5s
# Processed 270000/466176 samples (270/467 batches), elapsed: 238.0s, ETA: 173.7s
# Processed 280000/466176 samples (280/467 batches), elapsed: 246.8s, ETA: 164.8s
# Processed 290000/466176 samples (290/467 batches), elapsed: 255.6s, ETA: 156.0s
# Processed 300000/466176 samples (300/467 batches), elapsed: 264.4s, ETA: 147.2s
# Processed 310000/466176 samples (310/467 batches), elapsed: 273.2s, ETA: 138.3s
# Processed 320000/466176 samples (320/467 batches), elapsed: 281.9s, ETA: 129.5s
# Processed 330000/466176 samples (330/467 batches), elapsed: 290.7s, ETA: 120.7s
# Processed 340000/466176 samples (340/467 batches), elapsed: 299.5s, ETA: 111.9s
# Processed 350000/466176 samples (350/467 batches), elapsed: 308.3s, ETA: 103.1s
# Processed 360000/466176 samples (360/467 batches), elapsed: 317.1s, ETA: 94.2s
# Processed 370000/466176 samples (370/467 batches), elapsed: 325.8s, ETA: 85.4s
# Processed 380000/466176 samples (380/467 batches), elapsed: 334.6s, ETA: 76.6s
# Processed 390000/466176 samples (390/467 batches), elapsed: 343.4s, ETA: 67.8s
# Processed 400000/466176 samples (400/467 batches), elapsed: 352.2s, ETA: 59.0s
# Processed 410000/466176 samples (410/467 batches), elapsed: 360.9s, ETA: 50.2s
# Processed 420000/466176 samples (420/467 batches), elapsed: 369.7s, ETA: 41.4s
# Processed 430000/466176 samples (430/467 batches), elapsed: 378.5s, ETA: 32.6s
# Processed 440000/466176 samples (440/467 batches), elapsed: 387.3s, ETA: 23.8s
# Processed 450000/466176 samples (450/467 batches), elapsed: 396.1s, ETA: 15.0s
# Processed 460000/466176 samples (460/467 batches), elapsed: 404.8s, ETA: 6.2s
# Prediction time: 409.48 seconds
#
# === Processing label: level0_annotation ===
# Training time: 0.09 seconds
# Predicting level0_annotation in batches...
# Processed 10000/466176 samples (10/467 batches), elapsed: 9.6s, ETA: 440.8s
# Processed 20000/466176 samples (20/467 batches), elapsed: 18.4s, ETA: 412.1s
# Processed 30000/466176 samples (30/467 batches), elapsed: 27.2s, ETA: 396.6s
# Processed 40000/466176 samples (40/467 batches), elapsed: 36.0s, ETA: 384.6s
# Processed 50000/466176 samples (50/467 batches), elapsed: 44.8s, ETA: 373.8s
# Processed 60000/466176 samples (60/467 batches), elapsed: 53.6s, ETA: 363.5s
# Processed 70000/466176 samples (70/467 batches), elapsed: 62.4s, ETA: 353.8s
# Processed 80000/466176 samples (80/467 batches), elapsed: 71.2s, ETA: 344.3s
# Processed 90000/466176 samples (90/467 batches), elapsed: 80.0s, ETA: 335.0s
# Processed 100000/466176 samples (100/467 batches), elapsed: 88.8s, ETA: 325.8s
# Processed 110000/466176 samples (110/467 batches), elapsed: 97.5s, ETA: 316.6s
# Processed 120000/466176 samples (120/467 batches), elapsed: 106.3s, ETA: 307.5s
# Processed 130000/466176 samples (130/467 batches), elapsed: 115.1s, ETA: 298.5s
# Processed 140000/466176 samples (140/467 batches), elapsed: 123.9s, ETA: 289.5s
# Processed 150000/466176 samples (150/467 batches), elapsed: 132.7s, ETA: 280.5s
# Processed 160000/466176 samples (160/467 batches), elapsed: 141.5s, ETA: 271.5s
# Processed 170000/466176 samples (170/467 batches), elapsed: 150.3s, ETA: 262.5s
# Processed 180000/466176 samples (180/467 batches), elapsed: 159.0s, ETA: 253.6s
# Processed 190000/466176 samples (190/467 batches), elapsed: 167.8s, ETA: 244.7s
# Processed 200000/466176 samples (200/467 batches), elapsed: 176.6s, ETA: 235.8s
# Processed 210000/466176 samples (210/467 batches), elapsed: 185.4s, ETA: 226.9s
# Processed 220000/466176 samples (220/467 batches), elapsed: 194.2s, ETA: 218.0s
# Processed 230000/466176 samples (230/467 batches), elapsed: 202.9s, ETA: 209.1s
# Processed 240000/466176 samples (240/467 batches), elapsed: 211.7s, ETA: 200.2s
# Processed 250000/466176 samples (250/467 batches), elapsed: 220.5s, ETA: 191.4s
# Processed 260000/466176 samples (260/467 batches), elapsed: 229.2s, ETA: 182.5s
# Processed 270000/466176 samples (270/467 batches), elapsed: 238.0s, ETA: 173.7s
# Processed 280000/466176 samples (280/467 batches), elapsed: 246.8s, ETA: 164.8s
# Processed 290000/466176 samples (290/467 batches), elapsed: 255.6s, ETA: 156.0s
# Processed 300000/466176 samples (300/467 batches), elapsed: 264.4s, ETA: 147.2s
# Processed 310000/466176 samples (310/467 batches), elapsed: 273.1s, ETA: 138.3s
# Processed 320000/466176 samples (320/467 batches), elapsed: 281.9s, ETA: 129.5s
# Processed 330000/466176 samples (330/467 batches), elapsed: 290.7s, ETA: 120.7s
# Processed 340000/466176 samples (340/467 batches), elapsed: 299.5s, ETA: 111.9s
# Processed 350000/466176 samples (350/467 batches), elapsed: 308.3s, ETA: 103.0s
# Processed 360000/466176 samples (360/467 batches), elapsed: 317.1s, ETA: 94.2s
# Processed 370000/466176 samples (370/467 batches), elapsed: 325.8s, ETA: 85.4s
# Processed 380000/466176 samples (380/467 batches), elapsed: 334.6s, ETA: 76.6s
# Processed 390000/466176 samples (390/467 batches), elapsed: 343.4s, ETA: 67.8s
# Processed 400000/466176 samples (400/467 batches), elapsed: 352.2s, ETA: 59.0s
# Processed 410000/466176 samples (410/467 batches), elapsed: 361.0s, ETA: 50.2s
# Processed 420000/466176 samples (420/467 batches), elapsed: 369.8s, ETA: 41.4s
# Processed 430000/466176 samples (430/467 batches), elapsed: 378.6s, ETA: 32.6s
# Processed 440000/466176 samples (440/467 batches), elapsed: 387.4s, ETA: 23.8s
# Processed 450000/466176 samples (450/467 batches), elapsed: 396.2s, ETA: 15.0s
# Processed 460000/466176 samples (460/467 batches), elapsed: 404.9s, ETA: 6.2s
# Prediction time: 409.63 seconds
#
# ✅ All predictions completed.

# %%
eval_df
# Out:
#                                 spot organ     subregion    level1_annotation  \
# Unnamed: 0
# 1           AACAACGACAGCCTACAA_0_0_0    LU       Alveoli  blood & immune cell
# 11          AACACACGGTACAGAGCT_0_0_0    LU       Alveoli  blood & immune cell
# 12          AACACACGGTACGGCATA_0_0_0    LU       Alveoli      epithelial cell
# 20          AACACTACGCGAACGGTA_0_0_0    LU       Alveoli      epithelial cell
# 24          AACACTACGGTCCACCAA_0_0_0    LU       Alveoli      epithelial cell
# ...                              ...   ...           ...                  ...
# 2330867         TTGTTGACCGTGTACACT_1    HE  Heart Tissue          muscle cell
# 2330869         TTGTTGACCTCTTGACAG_1    HE  Heart Tissue          muscle cell
# 2330870         TTGTTGCGAAGATGCGTC_1    HE  Heart Tissue          muscle cell
# 2330872         TTGTTGCGAGTCTTCACA_1    HE  Heart Tissue          muscle cell
# 2330875         TTGTTGGAGCGCTTCTTC_1    HE  Heart Tissue          muscle cell
#
#                       level2_annotation    level0_annotation  \
# Unnamed: 0
# 1                                B cell               B cell
# 11                               B cell               B cell
# 12          specialized epithelial cell      epithelial cell
# 20                           pneumocyte    type I pneumocyte
# 24                           pneumocyte    type I pneumocyte
# ...                                 ...                  ...
# 2330867             cardiac muscle cell  cardiac muscle cell
# 2330869             cardiac muscle cell  cardiac muscle cell
# 2330870             cardiac muscle cell  cardiac muscle cell
# 2330872             cardiac muscle cell  cardiac muscle cell
# 2330875             cardiac muscle cell  cardiac muscle cell
#
#            celltype_prediction_1  score_prediction_1  \
# Unnamed: 0
# 1                         B cell              0.4480
# 11                        B cell              0.5057
# 12               epithelial cell              0.4006
# 20             type I pneumocyte              0.8655
# 24             type I pneumocyte              1.0000
# ...                          ...                 ...
# 2330867      cardiac muscle cell              0.5973
# 2330869      cardiac muscle cell              0.8586
# 2330870      cardiac muscle cell              0.6812
# 2330872      cardiac muscle cell              0.4873
# 2330875      cardiac muscle cell              0.5192
#
#                      celltype_prediction_2  score_prediction_2  ...  \
# Unnamed: 0                                                      ...
# 1                          epithelial cell              0.2924  ...
# 11                         epithelial cell              0.2555  ...
# 12                                  T cell              0.3183  ...
# 20                        endothelial cell              0.0980  ...
# 24                                     NaN              0.0000  ...
# ...                                    ...                 ...  ...
# 2330867                         fibroblast              0.2106  ...
# 2330869     regular atrial cardiac myocyte              0.1414  ...
# 2330870                         fibroblast              0.1929  ...
# 2330872       fibroblast of cardiac tissue              0.2563  ...
# 2330875     regular atrial cardiac myocyte              0.3176  ...
#
#            organ_encoded  subregion_encoded  level0_annotation_encoded  \
# Unnamed: 0
# 1                      8                  0                          0
# 11                     8                  0                          0
# 12                     8                  0                        104
# 20                     8                  0                        339
# 24                     8                  0                        339
# ...                  ...                ...                        ...
# 2330867                4                 17                         61
# 2330869                4                 17                         61
# 2330870                4                 17                         61
# 2330872                4                 17                         61
# 2330875                4                 17                         61
#
#             level1_annotation_encoded  level2_annotation_encoded  organ_pred  \
# Unnamed: 0
# 1                                   1                          0          LU
# 11                                  1                          0          LU
# 12                                  6                         68          LU
# 20                                  6                         58          LU
# 24                                  6                         58          LU
# ...                               ...                        ...         ...
# 2330867                            13                          7          HE
# 2330869                            13                          7          HE
# 2330870                            13                          7          HE
# 2330872                            13                          7          HE
# 2330875                            13                          7          HE
#
#            subregion_pred  level1_annotation_pred  \
# Unnamed: 0
# 1                 Alveoli         epithelial cell
# 11                Alveoli         epithelial cell
# 12                Alveoli     blood & immune cell
# 20                Alveoli         epithelial cell
# 24                Alveoli     blood & immune cell
# ...                   ...                     ...
# 2330867      Heart Tissue             muscle cell
# 2330869      Heart Tissue             muscle cell
# 2330870      Heart Tissue             muscle cell
# 2330872      Heart Tissue             muscle cell
# 2330875      Heart Tissue             muscle cell
#
#                  level2_annotation_pred          level0_annotation_pred
# Unnamed: 0
# 1                      endothelial cell                endothelial cell
# 11          specialized epithelial cell                       club cell
# 12                           macrophage             alveolar macrophage
# 20                           pneumocyte                          T cell
# 24                               B cell                          B cell
# ...                                 ...                             ...
# 2330867             cardiac muscle cell             cardiac muscle cell
# 2330869             cardiac muscle cell             cardiac muscle cell
# 2330870             cardiac muscle cell             cardiac muscle cell
# 2330872             cardiac muscle cell             cardiac muscle cell
# 2330875             cardiac muscle cell  regular atrial cardiac myocyte
#
# [466176 rows x 27 columns]

# %%
# Save
eval_df.to_csv(f"/home/lbh/projects_dir/BigSlice/evalset/uni_prediction_{patch_size}_for_validation_coo_norm_fin.csv")
